# %% [markdown]
# ___
#
# <a> <img src='DataWorkflow_LowRes.png' width="600"/></a>
# ___
# # Data Workflow Crash Course
#
# Please note, this is not meant to be a comprehensive overview of Python or programming or recomended data workflows. It is simply to give some examples of what your process may resemble.
#
# **This notebook is just a potential reference, any and all of the example can be altered or a different approach taken altogether.**
# ____

# %% [markdown]
# ## Analysis
# This is the stage where the data will be combined analyzed to find trends, significance, create charts, and determine experimental results. It can roughly be divided into (1) exploratory data analysis, (2) statistical tests of significance, and (3) modeling results.
#
# [<img src="References/Statistical Test Decision Tree.png">](https://tales.nmc.unibas.ch/de/conducting-psychological-research-6/statistics-and-analyses-22/which-test-for-which-hypothesis-71)

# %% [markdown]
# ### Import Libraries for Use

# %%
import pandas as pd
import datetime as dt
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %matplotlib inline

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# This is the stage of performing initial investigations on data to look for patterns, anomalies, check assumptions, and determine hypothesis testing.

# %%
# Import dataframes of initial data
df_weather = pd.read_excel('Example_HourlyWeatherData.xlsx')
df_lab = pd.read_excel('Example_MultivariateExperiments.xlsx')
df_timeseries = pd.read_excel('Example_TimeSeriesProductivity.xlsx')

# Import processed data
df_daily_timeseries = pd.read_excel('Exports/Daily Timeseries.xlsx')
df_grouped_timeseries = pd.read_excel('Exports/Grouped Timeseries.xlsx')

# Drop air temperature from lab data
df_lab = df_lab.drop(['Air_Temp'], axis=1)

# %% [markdown]
# #### EDA on Laboratory Experiments
# The below is only an example of some methods. There are many more and the style for each can be changed too.

# %%
# Summary Statistics
df = df_lab
df = df.groupby(['Experiment'], as_index=False).agg(
                      {'Productivity':['mean','std','median','min','max']})
df
# Out:
#    Experiment Productivity
#                       mean       std    median       min       max
# 0           1     5.166744  0.633044   4.98060   4.48254   6.47478
# 1           2     5.590989  0.746867   5.45664   4.54720   6.65028
# 2           3     5.934769  0.733365   6.06736   4.66720   6.88412
# 3           4     9.794018  1.243148  10.20138   7.81788  11.25012
# 4           5     9.789644  1.449662   9.97452   8.03772  11.62080
# 5           6     9.896580  1.126646   9.73566   8.16222  11.60412
# 6           7    13.460178  1.922937  12.45128  11.23322  15.97012
# 7           8    14.355760  1.406798  14.77872  12.17876  16.42080
# 8           9    13.544744  1.507150  14.11068  11.34388  15.49408
# 9          10     6.136411  0.697973   6.32636   4.81732   6.90676
# 10         11     6.110969  0.597939   6.07308   5.35860   7.02572
# 11         12     6.525731  0.752777   6.77544   5.12736   7.32480
# 12         13    10.240724  1.258097  10.68636   7.84320  11.47068
# 13         14     9.944951  1.212146   9.85446   8.36136  11.74572
# 14         15     9.837622  0.851705  10.00296   8.38632  11.21544
# 15         16    13.804000  1.723013  14.21812  11.31928  16.56480
# 16         17    13.053333  1.502067  12.83768  11.30274  16.60526
# 17         18    13.950138  1.934311  13.82192  11.28320  16.92480
# 18         19     6.189958  0.566841   6.31696   5.16290   6.98510
# 19         20     6.071229  0.580779   6.03728   5.10368   7.03312
# 20         21     6.599987  0.709414   6.56522   5.22668   7.64880
# 21         22     9.579458  1.223445   9.26808   8.15994  11.98806
# 22         23    10.623665  1.163431  10.93968   8.69040  12.06432
# 23         24    10.845545  0.953464  11.20392   9.54408  12.34506
# 24         25    13.792520  1.478775  13.79252  11.96290  16.60732
# 25         26    14.004175  1.580546  13.65504  12.09040  16.35760
# 26         27    15.275642  1.568138  15.09270  11.93042  17.24880

# %%
# Boxplot
df = df_lab
plt.figure(figsize=(16, 6))
sns.boxplot(x=df["Experiment"], y=df["Productivity"] )
# Out:
# <AxesSubplot:xlabel='Experiment', ylabel='Productivity'>

# %%
# Grouped Violin Plot
df = df_lab
plt.figure(figsize=(16, 6))
sns.boxplot(x=df["Experiment"], y=df["Productivity"], hue=df["PPF"])
# Out:
# <AxesSubplot:xlabel='Experiment', ylabel='Productivity'>

# %%
# Violin Plot
df = df_lab
plt.figure(figsize=(16, 6))
sns.violinplot(x=df["Experiment"], y=df["Productivity"] )
# Out:
# <AxesSubplot:xlabel='Experiment', ylabel='Productivity'>

# %%
# Grouped Violin Plot
df = df_lab
plt.figure(figsize=(16, 6))
sns.violinplot(x=df["Experiment"], y=df["Productivity"], hue=df["PPF"])
# Out:
# <AxesSubplot:xlabel='Experiment', ylabel='Productivity'>

# %%
# Pairplot
df = df_lab
sns.pairplot(df)

# %%
# Pairplot
df = df_lab
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Correlation
df = df_lab
df.corr()
# Out:
#               Experiment         Light           PPF    Water_Temp  \
# Experiment      1.000000  9.434564e-01  3.144855e-01  1.048285e-01
# Light           0.943456  1.000000e+00 -4.338218e-16  3.604549e-16
# PPF             0.314485 -4.338218e-16  1.000000e+00  3.760852e-16
# Water_Temp      0.104828  3.604549e-16  3.760852e-16  1.000000e+00
# Productivity    0.366034  7.151772e-02  9.307790e-01  5.574076e-02
#
#               Productivity
# Experiment        0.366034
# Light             0.071518
# PPF               0.930779
# Water_Temp        0.055741
# Productivity      1.000000

# %%
df
# Out:
#      Experiment  Light   PPF  Air_Temp  Water_Temp  Productivity
# 0             1    600   400        23          15       5.20196
# 1             1    600   400        23          15       4.53788
# 2             1    600   400        23          15       4.86992
# 3             1    600   400        23          15       4.75924
# 4             1    600   400        23          15       5.70002
# ..          ...    ...   ...       ...         ...           ...
# 292          27    960  1200        23          25      11.93042
# 293          27    960  1200        23          25      16.96132
# 294          27    960  1200        23          25      14.23026
# 295          27    960  1200        23          25      14.51774
# 296          27    960  1200        23          25      17.24880
#
# [297 rows x 6 columns]
